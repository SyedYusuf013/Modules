# %%
import math

# %%
mt.sqrt(4)
# Out:
# 2.0

# %%
from math import sqrt

# %%
sqrt(5)
# Out:
# 2.23606797749979

# %%
from math import sqrt , pi

# %%
pi
# Out:
# 3.141592653589793

# %%
from math import *

# %%
sin(0)
# Out:
# 0.0

# %%
sqrt(7)
# Out:
# 2.6457513110645907

# %%
pi
# Out:
# 3.141592653589793

# %%
pwd()
# Out:
# 'C:\\Users\\syedf'

# %%
import test1
# Out:
# this is my first ever module

# %%
import test1

# %%
import test1

# %%
import test1

# %%
 import imp

# %%
imp.reload(test1)
# Out:
# this is my first ever module
# <module 'test1' from 'C:\\Users\\syedf\\test1.py'>

# %%
import addition

# %%
addition.addition1(5,3)
# Out:
# 8

# %%
import test6

# %%
test6.msg()
# Out:
# 'this is my class '

# %%
test6.get_course()

# %%
test6.get_course()

# %%
from test6 import get_course

# %%
print(k+p)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_308/3855869764.py in <module>
# ----> 1 print(k+p)
#
# NameError: name 'k' is not defined

# %%
def two_two(k,p):
    print(k+p)

# %%
two_two(5,6)
# Out:
# 11

# %%
import mod1
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_308/1766116365.py in <module>
# ----> 1 import mod1
#
# ModuleNotFoundError: No module named 'mod1'

# %%
import test1

# %%
import test

# %%
import mod1
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_308/1766116365.py in <module>
# ----> 1 import mod1
#
# ModuleNotFoundError: No module named 'mod1'

# %%
pwd()
# Out:
# 'C:\\Users\\syedf'

# %%
import os

# %%
pwd()
# Out:
# 'C:\\Users\\syedf'

# %%
os.chdir('C:\\Users\\syedf\\test1')

# %%
pwd()
# Out:
# 'C:\\Users\\syedf\\test1'

# %%
os.chdir('C:\\Users\\syedf\\test1\\test')

# %%
pwd()
# Out:
# 'C:\\Users\\syedf\\test1\\test'

# %%
import mod1

# %%
import mod2

# %%
import mod3

# %%
import all
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_308/1688680014.py in <module>
# ----> 1 import all
#
# ModuleNotFoundError: No module named 'all'

# %%
import mod1,mod2,mod3

# %%
pwd()
# Out:
# 'C:\\Users\\syedf\\test1\\test'

# %%
os.chdir('C:\\Users\\syedf')

# %%
pwd()
# Out:
# 'C:\\Users\\syedf'

# %%
import mod1

# %%
pwd()
# Out:
# 'C:\\Users\\syedf'

# %%
pwd()
# Out:
# 'C:\\Users\\syedf'

# %%
#######exceptional handling
######
#@#####
#####

# %%
######

# %%
print("sjkkdgfksdgf s)
# Out:
#   File "C:\Users\syedf\AppData\Local\Temp/ipykernel_308/366373504.py", line 1
#     print("sjkkdgfksdgf s)
#                           ^
# SyntaxError: EOL while scanning string literal

# %%
def test(a,b):
    return a/b

# %%
test(5/0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_308/3378878339.py in <module>
# ----> 1 test(5/0)
#
# ZeroDivisionError: division by zero

# %%
test(5,0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_308/2318398676.py in <module>
# ----> 1 test(5,0)
#
# ~\AppData\Local\Temp/ipykernel_308/2149075966.py in test(a, b)
#       1 def test(a,b):
# ----> 2     return a/b
#
# ZeroDivisionError: division by zero

# %%
test(6,7)
# Out:
# 0.8571428571428571

# %%
a = open("gest.txt",'r')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_308/3780114629.py in <module>
# ----> 1 a = open("gest.txt",'r')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'gest.txt'

# %%
try :
    a =open("gest.txt",'r')
except:
    print("there is  some issue with my code ")
# Out:
# there is  some issue with my code

# %%
try :
    a =open("gest.txt",'r')
except IOError:
    print("there is  some issue with my code ")
# Out:
# there is  some issue with my code

# %%
try :
    a=int(input("enter the first no."))
    b = int(input("enter the second no."))
    c = a/b
except ArithmeticError as e:
    print("there is  some issue with my code ", e)
    f = open("gest.txt", "w+")
    f.read()
else :
    print("this will execute once try will execute with sucess  ")
    try:
        f=open("gest.txt","r")
    except :
        print("this is as issue with internal try block ")
# Out:
# enter the first no.5
# enter the second no.0
# there is  some issue with my code  division by zero

# %%
l=[4,5,6,7,8,9,0]

# %%
l[100]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15112/2321736930.py in <module>
# ----> 1 l[100]
#
# IndexError: list index out of range

# %%
l = [4,5,6,7,8,9,0]
print(l[100])
t =(4,5,6,7,7,8,9) 
print(t)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15112/1214624020.py in <module>
#       1 l = [4,5,6,7,8,9,0]
# ----> 2 print(l[100])
#       3 t =(4,5,6,7,7,8,9)
#       4 print(t)
#
# IndexError: list index out of range

# %%
try :
    l=[4,5,6,7,8,9]
    print(l[100])
except:
    print("there is an issue with my code ")
    t=(4,5,6,7,7,8,9)
    print(t)
else:
    print("there is no issue with my code ")
# Out:
# there is an issue with my code
# (4, 5, 6, 7, 7, 8, 9)

# %%
try:
    l=[4,5,6,7,8,9,]
    l[100]
except :
    print("there is an issue with my code ")
    t=(4,5,6,7,7,8,9)
    print(t)
    try :
        
        
        t[0]= "syed"
        try :
            list (t)
            print(t)
        except :
            pass
    except:
        pass
else:
    print("there is no issue with my code ")
# Out:
# there is an issue with my code
# (4, 5, 6, 7, 7, 8, 9)

# %%
try :
    f = open("gest.txt","r")
except:
    pass

# %%
try :
    f = open("gest1.txt",'r')
finally:
    print("finally i will execute in any case")
    l = [4,5,6,7]
    print(l[0])
# Out:
# finally i will execute in any case
# 4
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24212/2849718588.py in <module>
#       1 try :
# ----> 2     f = open("gest1.txt",'r')
#       3 finally:
#       4     print("finally i will execute in any case")
#       5     l = [4,5,6,7]
#
# FileNotFoundError: [Errno 2] No such file or directory: 'gest1.txt'

# %%
try :
    f = open("gest1.txt",'r')
finally:
    print("finally i will execute in any case")
    l = [4,5,6,7]
    print(l[10])
# Out:
# finally i will execute in any case
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24212/2416229570.py in <module>
#       1 try :
# ----> 2     f = open("gest1.txt",'r')
#       3 finally:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'gest1.txt'
#
# During handling of the above exception, another exception occurred:
#
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24212/2416229570.py in <module>
#       4     print("finally i will execute in any case")
#       5     l = [4,5,6,7]
# ----> 6     print(l[10])
#
# IndexError: list index out of range

# %%
try :
    f = open("gest1.txt",'w+')
except:
    pass
else:
    print("else will execute if try will execute with success ")
finally:
    print("finally i will execute in any case")
    l = [4,5,6,7]
    try:
        
        print(l[10])
    except:
        pass
# Out:
# else will execute if try will execute with success
# finally i will execute in any case

# %%
5/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24212/2874912419.py in <module>
# ----> 1 5/0
#
# ZeroDivisionError: division by zero

# %%
5/6
# Out:
# 0.8333333333333334

# %%
try :
    f = open("gest3.txt","r")
except IOError:
    print("this is my error")
# Out:
# this is my error

# %%
try :
    f = open("gest3.txt","r")
except IOError as e:
    print("this is my error" , e)
# Out:
# this is my error [Errno 2] No such file or directory: 'gest3.txt'

# %%
 open("gest3.txt","r")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24212/3551654940.py in <module>
# ----> 1 open("gest3.txt","r")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'gest3.txt'

# %%
def askforint():
    while True:
        try :
            a = int(input("enter an integer  "))
        except Exception as e:
            print("this is my error msg " , e)
        else:
            print("person has entered a correct value ")
        finally:
            print("close this issue ")

# %%
askforint()

# %%
def forint():
    while True:
        try :
            a = int(input("enter an integer  "))
        except Exception as e:
            print("this is my error msg " , e)
            continue 
        else:
            print("person has entered a correct value ")
            break
        finally:
            print("close this issue ")

# %%
forint()
# Out:
# enter an integer  dgf
# this is my error msg  invalid literal for int() with base 10: 'dgf'
# close this issue
# enter an integer  dfgh
# this is my error msg  invalid literal for int() with base 10: 'dfgh'
# close this issue
# enter an integer  fghgh
# this is my error msg  invalid literal for int() with base 10: 'fghgh'
# close this issue

# %%
 def forint():
    while True:
        try :
            a = int(input("enter an integer  "))
        except Exception as e:
            print("this is my error msg " , e)
            continue 
        else:
            print("person has entered a correct value ")
            break
        finally:
            break
            print("close this issue ")

# %%
forint()
# Out:
# enter an integer  vngvn
# this is my error msg  invalid literal for int() with base 10: 'vngvn'

# %%
def forint():
    while True:
        try :
            a = int(input("enter an integer  "))
        except FileNotFoundError as e:
            print("this is my error msg " , e) 
        except IOError as e:
            print(e)
        except ValueError as e :
            print(e)
        else:
            print("person has entered a correct value ")
            break
        finally:
            print("close this issue ")

# %%
forint()
# Out:
# enter an integer  hgfh
# invalid literal for int() with base 10: 'hgfh'
# close this issue
# enter an integer  gfgd
# invalid literal for int() with base 10: 'gfgd'
# close this issue
# enter an integer
# invalid literal for int() with base 10: ''
# close this issue
# enter an integer
# invalid literal for int() with base 10: ''
# close this issue
# enter an integer  hfgh
# invalid literal for int() with base 10: 'hfgh'
# close this issue
# enter an integer
# invalid literal for int() with base 10: ''
# close this issue
# enter an integer
# invalid literal for int() with base 10: ''
# close this issue

# %%
def askforint():
    while True:
        try :
            a = int(input("enter an integer "))
            c = 8/a
        except FileNotFoundError as e :
            print("this is my error msg " , e )
        except IOError as e:
            print (e)
        except ValueError as e:
            print(e)
        except Exception as e:
            print("this is comming from parent class ")
        except ArithmeticError as e :
            print("this is a arithimetic error")
        except ZeroDivisionError as e :
            print(e)
        else:
            print( "person has entered a correct value")
            break
        finally:
            print("close this issue")

# %%
askforint()
# Out:
# enter an integer 0
# this is comming from parent class
# close this issue

# %%
5/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_26760/2126900189.py in <module>
# ----> 1 5/0
#
# ZeroDivisionError: division by zero

# %%
5/6
# Out:
# 0.8333333333333334

# %%
def create_your_exception(a):
    if a ==6:
        raise Exception(a)
    else :
        print("inpuit is ok")
        
    return a

# %%
create_your_exception(6)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_26760/2402796548.py in <module>
# ----> 1 create_your_exception(6)
#
# ~\AppData\Local\Temp/ipykernel_26760/3032313896.py in create_your_exception(a)
#       1 def create_your_exception(a):
#       2     if a ==6:
# ----> 3         raise Exception(a)
#       4     else :
#       5         print("inpuit is ok")
#
# Exception: 6

# %%
create_your_exception(7)
# Out:
# inpuit is ok
# 7

# %%
def create_your_exception(a):
    if a > 6:
        raise Exception("error is " , a)
    else :
        print("inpuit is ok")
        
    return a

# %%
try :
    create_your_exception(10)
except Exception as e:
    print(e)
# Out:
# ('error is ', 10)
